# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Varibles

# %%
prices = [
	(1, 2.12),
	(2, 2.56),
	(3, 3.10),
	(4, 3.16),
	(5, 3.58),
	(6, 5.12),
	(7, 5.16),
	(8, 5.20),
	(9, 4.12),
	(10, 4.10),
	(11, 3.65),
	(12, 4.25),

]

# %%
df = pd.DataFrame(prices, columns=["month", "price"])
df = df.set_index("month")

# %% [markdown]
# ## Add priceUSD column

# %%
df = df.assign(priceUSD = lambda priceUSD: df['price'] / 4)
df
# Out:
#        price  priceUSD
# month
# 1       2.12    0.5300
# 2       2.56    0.6400
# 3       3.10    0.7750
# 4       3.16    0.7900
# 5       3.58    0.8950
# 6       5.12    1.2800
# 7       5.16    1.2900
# 8       5.20    1.3000
# 9       4.12    1.0300
# 10      4.10    1.0250
# 11      3.65    0.9125
# 12      4.25    1.0625

# %% [markdown]
# ## Create graph

# %%
df["priceUSD"].plot(title = "Price of goods (USD)", color = "red", linestyle = 'dashed', grid = True)
# Out:
# <Axes: title={'center': 'Price of goods (USD)'}, xlabel='month'>

# %% [markdown]
# ## Result
